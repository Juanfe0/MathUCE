# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanfe0/MathUCE/blob/main/RESUMEN_CLASE_5_DE_MATEMATICA_JUANFE_YAZAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **RESUMEN CLASE 5 DE MATEMATICA**

# %% [markdown]
# # ***📑 Aplicación a la Economía en Función Biyectiva y Compuesta.***

# %% [markdown]
# # 📊✨ **Funciones de Utilidad en Economía**
#
# ## 🌟 **Introducción**
#
# En economía, las funciones de utilidad son fundamentales para entender cómo los individuos toman decisiones de consumo. Estas funciones miden el nivel de satisfacción o bienestar derivado del consumo de distintos bienes y servicios. La utilidad es una medida abstracta que permite cuantificar las preferencias de los consumidores.
#
# ## 📐 **Definición**
#
# Una **función de utilidad** es una representación matemática que asigna un valor numérico a las diferentes combinaciones de bienes consumidos. Este valor refleja el nivel de satisfacción o utilidad que un consumidor obtiene.
#
# ## 🧮 **Ejemplo Práctico**
#
# Para ilustrar el concepto, consideremos una función de utilidad sencilla:
#
# $[ U(x, y) = x \times y ]$
#
# Donde:
# - $(x)$ representa la cantidad del bien A consumido.
# - $(y)$ representa la cantidad del bien B consumido.
#
# ## 🔍 **Interpretación**
#
# La función anterior indica que la utilidad total es proporcional al producto de las cantidades de los dos bienes consumidos. Esto sugiere que consumir más de ambos bienes aumenta la satisfacción del consumidor.
#
# ## 🚀 **Aplicaciones**
#
# Las funciones de utilidad son utilizadas en modelos económicos para:
# - **Determinar la cesta óptima de bienes**: Identificar qué combinaciones de bienes maximizan la utilidad.
# - **Estudiar el comportamiento del consumidor**: Comprender cómo las decisiones de consumo cambian en respuesta a variaciones en precios e ingresos.
# - **Analizar políticas económicas**: Evaluar el impacto de políticas sobre el bienestar de los individuos.

# %% [markdown]
# *   # 💧💭 **Función de Utilidad con un Solo Bien**
#
#
#
#
# ## 🌊 **Ejemplo Simple: Agua**
#
# Consideremos un ejemplo en el que el único bien disponible es el agua. La función de utilidad en este caso se representa como \( u(x) \), donde \( x \) es la cantidad de agua consumida y \( u(x) \) es la utilidad obtenida.
#
# ### 📈 **Relación Agua-Utilidad**
#
# $[ \text{Agua}(x) \rightarrow \text{Utilidad}(u(x)) ]$
#
# Gráficamente, esta relación se puede representar con una curva que muestra cómo la utilidad aumenta a medida que se consume más agua. Sin embargo, la **utilidad marginal** decrece, lo que significa que cada unidad adicional de agua proporciona una utilidad menor que la anterior.
#
# Por ejemplo, el primer vaso de agua puede proporcionar mucha satisfacción en un día caluroso, pero el tercer o cuarto vaso proporciona una satisfacción significativamente menor.
#
# ## 🔍 **Observaciones**
#
# - **Utilidad marginal decreciente**: A medida que aumenta el consumo, la utilidad adicional obtenida disminuye.
# - **Importancia del contexto**: El valor de cada unidad adicional depende de las circunstancias, como el clima o la sed.
#
# Este comportamiento refleja una característica común en muchas funciones de utilidad y es clave para entender las decisiones de consumo en la vida real.

# %% [markdown]
# *   # 💭✨ Funciones de Utilidad con Dos Bienes
#
#
#
#
# ## 🌊🥖 Introducción
#
# La situación se vuelve más interesante cuando consideramos dos bienes, como agua y pan. Ahora, la función de utilidad depende de ambas cantidades consumidas:
#
# $[ u(x, y) ]$
#
# Aquí, $( x )$ es la cantidad de agua y $( y )$ es la cantidad de pan. La utilidad se representa en un gráfico tridimensional, donde los ejes $( x )$ e $( y )$ corresponden a las cantidades de los dos bienes, y el eje vertical representa la utilidad. Esta representación gráfica muestra una **superficie de utilidad**.
#
# ## 🌐 Superficie de Utilidad
#
# Imaginemos una superficie en forma de concha acústica, donde cada punto en la superficie representa un nivel de utilidad específico asociado con una combinación particular de $( x )$  $( y )$. Si solo miramos desde el lado de $( x )$ o $( y )$, veremos curvas similares a las que teníamos en el caso unidimensional.
#
# ## 📊 Ejemplos de Funciones de Utilidad
#
# Ejemplos de funciones de utilidad que se ajustan a esta descripción incluyen:
#
# - $( \log(x) )$
# - $( \sqrt{x} )$
#
# Ambas funciones tienen la característica de ser crecientes pero con una pendiente cada vez menor, reflejando el principio de **utilidad marginal decreciente**.
#
# Estas funciones ayudan a modelar cómo la satisfacción de un consumidor cambia con el consumo de diferentes combinaciones de bienes, proporcionando una herramienta útil para el análisis económico.

# %% [markdown]
# *   # 🔢✨ Notación Matemática de la Función de Utilidad
#
#
#
# 1. **Definición de la Función de Utilidad**:
#    $[
#    U: \mathbb{R}^2_+ \rightarrow \mathbb{R}^+
#    ]$
#    Esta notación indica que la función de utilidad $( U )$ toma como entrada un par de números reales no negativos $(( \mathbb{R}^2_+ ))$ y produce un número real no negativo $(( \mathbb{R}^+ ))$.
#
# 2. **Expresión de la Función de Utilidad**:
#    $[
#    (x, y) \rightarrow u(x, y)
#    ]$
#    Aquí, $( (x, y) $) son las cantidades de dos bienes, y $( u(x, y) )$ es el nivel de utilidad asociado con esas cantidades.
#
# 3. **Conjuntos de Nivel**:
#    $[
#    \{ (x, y) \in \mathbb{R}^2_+ : u(x, y) = 10 \}
#    ]$
#    Esto representa el conjunto de todos los pares $( (x, y) )$ en $( \mathbb{R}^2_+ )$ que producen una utilidad de 10. En el gráfico, estos conjuntos de nivel están representados por **curvas de nivel** (isocuantas) en rojo.

# %% [markdown]
# # 📊 ***Gráfica de la Función de Utilidad en Python***

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definimos la función de utilidad
def u(x, y):
    return np.log(x) + np.sqrt(y)

# Rango de valores para x e y
x = np.linspace(0.1, 5, 400)  # evitamos x=0 para evitar log(0)
y = np.linspace(0, 10, 400)
X, Y = np.meshgrid(x, y)
Z = u(X, Y)

# Creamos la figura
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Gráfico de la superficie de la función de utilidad
ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.8)

# Contornos en el plano
contours = ax.contour(X, Y, Z, levels=[1, 2, 3, 4, 5, 10], cmap='autumn', linestyles="solid")

# Etiquetas y título
ax.set_xlabel('Bien X')
ax.set_ylabel('Bien Y')
ax.set_zlabel('Utilidad U(x, y)')
ax.set_title('Superficie de la Función de Utilidad y Conjuntos de Nivel')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # 📊🔍 Función de Utilidad: Conjuntos de Nivel y Preimagen
#
# En el análisis económico, los conjuntos de nivel y la preimagen de una función de utilidad son conceptos fundamentales que ayudan a entender cómo las combinaciones de consumo afectan la satisfacción del consumidor.
#
# ## 📈 Notación Matemática
#
# ### 🔍 Conjuntos de Nivel
#
# Los conjuntos de nivel de una función de utilidad $( u(x, y) )$ representan todas las combinaciones de bienes $( (x, y) )$ que proporcionan la misma utilidad.
#
# $[ f^{-1}(\{10\}) = \{ (x, y) \in \mathbb{R}^2_+ : u(x, y) = 10 \} ]$
#
# Para la función $( u(x, y) = \sqrt{xy} )$, el conjunto de nivel para una utilidad de 10 se define como:
#
# $[ \{ (x, y) \in \mathbb{R}^2_+ : \sqrt{xy} = 10 \} ]$
#
# Simplificando, obtenemos:
#
# $[ \{ (x, y) \in \mathbb{R}^2_+ : xy = 100 \} ]$
#
# O, de manera equivalente:
#
# $[ \{ (x, y) \in \mathbb{R}^2_+ : y = \frac{100}{x} \} ]$
#
# ### 🌐 Generalización para un Nivel de Utilidad \( u_0 \)
#
# Para un nivel de utilidad \( u_0 \), el conjunto de nivel se generaliza como:
#
# $[ f^{-1}(\{u_0\}) = \{ (x, y) \in \mathbb{R}^2_+ : y = \frac{u_0^2}{x} \} ]$
#
# Esto indica que, independientemente del valor específico de \( u_0 \), la relación entre $( x )$ e \( y )$, se mantiene según la ecuación.

# %% [markdown]
# # 📈🔍 Superficie de la Función de Utilidad y Conjuntos de Nivel
#
# En economía, la función de utilidad se representa frecuentemente como una superficie tridimensional donde los ejes $( x )$ e $( y )$ representan las cantidades de dos bienes diferentes, y el eje vertical representa el nivel de utilidad.
#
# ## 🌐 Superficie de Utilidad
#
# La función de utilidad $( u(x, y) )$ puede ser visualizada como una superficie en un espacio tridimensional. Cada punto en esta superficie representa un nivel de utilidad asociado con una combinación particular de cantidades $( (x, y) )$ de los bienes.

# %% [markdown]
# *   ***Gráfica superficie de la funcion de utilidad y conjuntos de nivel***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🔄 Curvas de Indiferencia de la Función de Utilidad
#
# En teoría económica, las curvas de indiferencia son representaciones gráficas que muestran las combinaciones de dos bienes que proporcionan la misma utilidad total a un consumidor. Estas curvas son fundamentales para entender las preferencias y decisiones de consumo.
#
# ## 📚 Definición
#
# Una curva de indiferencia para una función de utilidad $ u(x, y) $ es un conjunto de todas las combinaciones de cantidades $ (x, y) $ que proporcionan al consumidor la misma utilidad total. Matemáticamente, se define como:
#
# $$ u(x, y) = \text{constante} $$
#
# Esto implica que a lo largo de una curva de indiferencia, el consumidor es indiferente entre cualquier punto en la curva, ya que todos ofrecen la misma satisfacción.
#
# ## 📊 Características
#
# - **Declive**: Las curvas de indiferencia son descendentes de izquierda a derecha debido al principio de utilidad marginal decreciente. Esto significa que, para mantener la misma utilidad total, el consumidor debe recibir más de un bien cuando tiene menos del otro.
#
# - **Forma**: Las curvas de indiferencia pueden tener diferentes formas dependiendo de la función de utilidad. Por ejemplo, si $ u(x, y) = \sqrt{x} + \sqrt{y} $, las curvas de indiferencia serán cóncavas hacia el origen.
#
# ## 📈 Representación Gráfica
#
# En un plano $ xy $, cada curva de indiferencia representa una línea que conecta todos los puntos donde el consumidor se siente igualmente satisfecho en términos de utilidad. La combinación exacta de bienes en cualquier punto de una curva de indiferencia depende de las preferencias del consumidor.
#
# Las curvas de indiferencia son herramientas poderosas para analizar el comportamiento del consumidor y se utilizan extensamente en la teoría económica y la microeconomía.

# %% [markdown]
# - 📊 ***Curvas de indiferencia de la Función de Utilidad***

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función de utilidad cuadrática
def utility(x, y):
    return x**0.5 + y**0.5

# Valores de utilidad constante
utility_levels = [1, 2, 3]

# Crear un rango de valores para x e y
x = np.linspace(0.1, 5, 400)
y = np.linspace(0.1, 5, 400)
X, Y = np.meshgrid(x, y)

# Calcular las curvas de indiferencia
fig, ax = plt.subplots()

for u in utility_levels:
    Z = utility(X, Y)
    ax.contour(X, Y, Z, levels=[u], colors='b', linestyles='solid', linewidths=2)
    ax.text(0.1, 5, f'U={u}', fontsize=10)

ax.set_xlabel('Bien X')
ax.set_ylabel('Bien Y')
ax.set_title('Curvas de Indiferencia de la Función de Utilidad')
ax.grid(True)
plt.xlim(0, 5)
plt.yl

# %% [markdown]
# - ***Conjuntos de nivel de la funcion de Utilidad***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 💻 ***Función Sobreyectiva, Biyectiva, Inyectiva, Inversa y Compuesta***
#
# En matemáticas, especialmente en teoría de funciones, es fundamental entender diferentes tipos de funciones y sus propiedades. Aquí exploraremos las funciones sobreyectivas, biyectivas, inyectivas, así como sus inversas y composiciones.
#
# - ## 🎯 **Función Inyectiva**
#
# Una función $ f: A \to B $ es inyectiva si cada elemento de $ A $ se mapea a un único elemento de $ B $. Matemáticamente, para todo $ x_1, x_2 \in A $, si $ f(x_1) = f(x_2) $, entonces $ x_1 = x_2 $.
#
# - ## 🔄 **Función Sobreyectiva**
#
# Una función $ f: A \to B $ es sobreyectiva si cada elemento de $ B $ tiene al menos un preimagen en $ A $. Esto significa que para todo $ y \in B $, existe al menos un $ x \in A $ tal que $ f(x) = y $.
#
# - ## 🔗 **Función Biyectiva**
#
# Una función $ f: A \to B $ es biyectiva si es tanto inyectiva como sobreyectiva. Esto implica que cada elemento de $ A $ se relaciona de manera única con un elemento de $ B $, y que cada elemento de $ B $ tiene exactamente una preimagen en $ A $.
#
# - ## ↩️ Función Inversa
#
# Dada una función biyectiva $ f: A \to B $, su función inversa $ f^{-1}: B \to A $ está definida de manera que $ f^{-1}(f(x)) = x $ para todo $ x \in A $ y $ f(f^{-1}(y)) = y $ para todo $ y \in B $.
#
# - ## 🔀 **Función Compuesta**
#
# La composición de dos funciones $ f: A \to B $ y $ g: B \to C $ es una nueva función $ g \circ f: A \to C $, definida como $ (g \circ f)(x) = g(f(x)) $ para todo $ x \in A $.
#
# Estos conceptos son esenciales para el estudio y la aplicación de funciones en matemáticas, especialmente en álgebra y análisis. La comprensión de funciones inyectivas, sobreyectivas, biyectivas, inversas y compuestas permite modelar y resolver una variedad de problemas matemáticos y aplicaciones prácticas.

# %% [markdown]
# - ***Función Sobreyectiva, Biyectiva, Inyectiva, Inversa y Compuesta, en codigo***

# %%
# Definición de funciones

# Función Sobreyectiva
def f_sobreyectiva(x):
    return x**2

# Función Inyectiva
def f_inyectiva(x):
    return x

# Función Biyectiva
def f_biyectiva(x):
    return x

# Función Inversa
def inversa(x):
    return x**0.5  # Raíz cuadrada positiva

# Función Compuesta
def composicion(f, g, x):
    return f(g(x))

# Verificar sobreyectividad en un conjunto
def es_sobreyectiva(conjunto, funcion):
    imagenes = set()
    for elem in conjunto:
        imagen = funcion(elem)
        imagenes.add(imagen)
    return len(imagenes) == len(conjunto)

# Verificar inyectividad en un conjunto
def es_inyectiva(conjunto, funcion):
    imagenes = set()
    for elem in conjunto:
        imagen = funcion(elem)
        if imagen in imagenes:
            return False
        imagenes.add(imagen)
    return True

# Verificar biyectividad en un conjunto
def es_biyectiva(conjunto, funcion):
    return es_inyectiva(conjunto, funcion) and es_sobreyectiva(conjunto, funcion)

# Ejemplos de uso

# Conjunto de ejemplo
conjunto = set(range(-5, 6))  # Conjunto {-5, -4, ..., 4, 5}

# Función Sobreyectiva
print("Función Sobreyectiva:")
print(f"La función f(x) = x^2 es sobreyectiva en el conjunto {-5, -4, ..., 4, 5}?")
print("Respuesta:", es_sobreyectiva(conjunto, f_sobreyectiva))

# Función Inyectiva
print("\nFunción Inyectiva:")
print(f"La función f(x) = x es inyectiva en el conjunto {-5, -4, ..., 4, 5}?")
print("Respuesta:", es_inyectiva(conjunto, f_inyectiva))

# Función Biyectiva
print("\nFunción Biyectiva:")
print(f"La función f(x) = x es biyectiva en el conjunto {-5, -4, ..., 4, 5}?")
print("Respuesta:", es_biyectiva(conjunto, f_biyectiva))

# Función Inversa
print("\nFunción Inversa:")
valor_codominio = 4
print(f"El valor en el dominio que mapea a {valor_codominio} bajo la función inversa es: {inversa(valor_codominio)}")

# Función Compuesta
print("\nFunción Compuesta:")
def g(x):
    return x**2

def h(x):
    return x + 1

x = 2
print(f"El resultado de la composición g(h(x)) para x = {x} es: {composicion(g, h, x)}")

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***Explicación sobre Funciones Compuestas***
#
# ## 🔑 **Definiciones Iniciales:**
#
# Se definen tres conjuntos:
# - $ E $: Dominio inicial de la función $ f $.
# - $ F $: Codominio de $ f $ y dominio de $ g $.
# - $ G $: Codominio de la función $ g $.
#
# Se definen dos funciones:
# - $ f: E \rightarrow F $, donde $ f(x) = x^2 + 1 $.
# - $ g: F \rightarrow G $, donde $ g(y) = \sqrt{y} $.
#
# ## 🔑 **Función Compuesta:**
#
# La función compuesta $ g \circ f $ se define como:
# $[ (g \circ f)(x) = g(f(x)) = \sqrt{f(x)} = \sqrt{x^2 + 1} ]$
# Esta composición toma un elemento $ x $ de $ E $, aplica la función $ f $ para obtener $ f(x) $ en $ F $, y luego aplica la función $ g $ a $ f(x) $ para obtener $ g(f(x)) $ en $ G $.
#
# ## 🔑 **Ejemplo de Función Compuesta:**
#
# Se define la función $ h(x) $:
# $[ h(x) = \sqrt{x^2 + 1} ]$

# %% [markdown]
# *  ***Codigo de la Funcion Compuesta:***

# %%
# Definición de funciones para la composición
def g(x):
    return x**2

def h(x):
    return x + 1

# Función Compuesta
def composicion(f, g, x):
    return f(g(x))

# Ejemplo de uso de la función compuesta g(h(x))
x = 2
resultado = composicion(g, h, x)
print(f"El resultado de la composición g(h(x)) para x = {x} es: {resultado}")

# %% [markdown]
# - ***Grafica***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🌟 ***Conclusión sobre Funciones y su Aplicación***
#
# Las funciones inyectivas, sobreyectivas y biyectivas 🎯 juegan un papel crucial en la teoría de funciones, proporcionando una base sólida para comprender cómo los elementos de diferentes conjuntos están relacionados entre sí. Estas propiedades son fundamentales para asegurar que cada elemento de un conjunto tiene una correspondencia clara y única en otro conjunto, lo cual es esencial en muchas aplicaciones matemáticas y científicas 🧠📐.
#
# En el ámbito de la economía 📊, estas funciones se aplican para modelar relaciones entre variables económicas, como la utilidad y el consumo, permitiendo un análisis preciso de cómo los cambios en una variable afectan a otra. Las funciones compuestas 🔄, que combinan varias funciones en una, son especialmente útiles para describir procesos económicos complejos donde múltiples etapas de transformación o cambio están involucradas.
#
# Mediante la composición de funciones, podemos simplificar y resolver problemas que implican varias transformaciones sucesivas, ofreciendo una herramienta poderosa para la modelización y el análisis económico 💡💼. La visualización de estas funciones y sus composiciones no solo facilita la comprensión de sus propiedades teóricas, sino que también proporciona una representación clara y accesible de sus aplicaciones prácticas en economía y otros campos 📈.
